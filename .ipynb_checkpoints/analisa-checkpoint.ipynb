# %% [markdown]
# # Observasi

# %%
import json
import pymongo
from pymongo import MongoClient

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Apply the default theme
sns.set_theme()

# %% [markdown]
# # Pipeline

# %% [markdown]
# ## category

# %%
with open('category.json', 'r') as out:
    data = json.load(out)
    data = data[0]

# %%
datas = data['data']['categoryAllListLite']['categories']

# %%
def find_categ_name(id):
    for data in datas:
        if str(id) == str(data['id']):
            return data['name']
    return None

# %%
def categ_to_name(datas):
    for data in datas:
        name = find_categ_name(data['_id'])
        data['_id'] = name
        
    return datas

# %% [markdown]
# # Connecting Mongo

# %%
client = MongoClient('localhost:9700')
db = client.tokpedstat

# %% [markdown]
# # common function

# %%
def grafik(df, dimensi=[13, 9], name=None):
    fig_dims = dimensi
    fig, ax = plt.subplots(figsize=fig_dims)

    g = sns.barplot(data = df, x='_id', y='total', ax=ax)
    g.set_xticklabels(g.get_xticklabels(), rotation=40)
    
    if name:
        fig.savefig('img/{}.png'.format(name))
        
    plt.show(g)

# %% [markdown]
# # Stat By Category

# %%
aggr = [
    {
        "$group": {
            "_id": "$cat_id_1",
            "total": { "$sum": 1 }
        }
    }
]

hasil = db.product.aggregate(aggr)
hasil = list(hasil)
hasil = categ_to_name(hasil)
df = pd.DataFrame.from_records(hasil)
df = df.fillna(value='kosong')

# %%
grafik(df, (15,8), 'kategori')

# %% [markdown]
# # Timeline created data

# %%
aggr = [
    {
        "$group": {
            "_id": { "$dateToString": { "format": "%Y-%m-%d", "date": "$created" } },
            "total": { "$sum": 1 }
        }
    }
]

hasilc = db.product.aggregate(aggr)
hasilc = list(hasilc)
df = pd.DataFrame.from_records(hasilc)
df = df.fillna(value='kosong')

# %%
grafik(df, (15,8), 'create')

# %% [markdown]
# ## Without null Value

# %%
cleanhasilc = list(filter(lambda x:bool(x), hasilc))
df = pd.DataFrame.from_records(cleanhasilc)
df.describe()
# Out:
#               total
# count  2.700000e+01
# mean   6.711700e+04
# std    2.901227e+05
# min    2.510000e+03
# 25%    6.062500e+03
# 50%    1.245900e+04
# 75%    1.541000e+04
# max    1.518587e+06

# %%
grafik(df, (15,8), 'create_not_null')

# %% [markdown]
# # Checking Last up Data

# %%
aggr = [ 
    {
        "$group": {
            "_id": { "$dateToString": { "format": "%Y-%m-%d", "date": "$last_updated" } },
            "total": { "$sum": 1 }
        }
    }
]

hasillast = db.product.aggregate(aggr)
hasillast = list(hasillast)
df = pd.DataFrame.from_records(hasillast)
df = df.fillna(value='kosong')
df.describe()
# Out:
#               total
# count  3.000000e+00
# mean   6.040540e+05
# std    9.316197e+05
# min    1.000000e+00
# 25%    6.760100e+04
# 50%    1.352010e+05
# 75%    9.060805e+05
# max    1.676960e+06

# %%
grafik(df, (15,8), 'last_update')

# %% [markdown]
# # Statistik Toko

# %%
aggr = [
    {
        "$group": {
            "_id": { "$dateToString": { "format": "%Y-%m-%d", "date": "$created" } },
            "total": { "$sum": 1 }
        }
    }
]

hasilc = db.toko.aggregate(aggr)
hasilc = list(hasilc)
df = pd.DataFrame.from_records(hasilc)
df = df.fillna(value='kosong')

# %%
grafik(df, (15,8), 'shop_created')

# %%
cleanhasilc = list(filter(lambda x:bool(x), hasilc))
df = pd.DataFrame.from_records(cleanhasilc)

# %%
grafik(df, (15,8), 'shop_created_notnull')

# %%
aggr = [
    { "$match": { "rating": { "$gte": 5 } }},
    {
        "$group": {
            "_id": "$location",
            "total": { "$sum": 1 }
        }
    },
    { "$sort": { "total": -1 } },
    { "$limit": 20 }
]

hasil = db.toko.aggregate(aggr)
hasil = list(hasil)

# %%
df = pd.DataFrame.from_records(hasil)
df = df.fillna(value='kosong')

fig_dims = (15, 11)
fig, ax = plt.subplots(figsize=fig_dims)

g = sns.barplot(data = df, x='_id', y='total', ax=ax)
g.set_xticklabels(g.get_xticklabels(), rotation=40)
plt.show(g)

# %% [markdown]
# # query data

# %%
db.product.count()
# Out:
# f:\python3\environment\test\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 1812163

# %% [markdown]
# # Kota

# %%
aggr = [
    {
        "$group": {
            "_id": "$location",
            "total": { "$sum": 1 }
        }
    },
    { "$sort": { "total": -1 } },
    { "$limit": 20 }
]

hasil = db.toko.aggregate(aggr)
hasil = list(hasil)

# %% [markdown]
# # stat produk

# %%
db.product.find_one()
# Out:
# {'_id': 406936069,
#  'shop': {'_id': 338447,
#   'username': 'ferrygolf75',
#   'percent_tx': 97.635,
#   'location': 'Jakarta Timur',
#   'rating': 4.8,
#   'score_map': 11,
#   'kecepatan': 4},
#  'itemid': 406936069,
#  'name': 'Tee Karet Driving Golf Rubber 5,6,7',
#  'price': 25000,
#  'shopid': 338447,
#  'url': 'https://www.tokopedia.com/ferrygolf75/tee-karet-driving-golf-rubber-5-6-7',
#  'description': '',
#  'weight': 10,
#  'last_updated': datetime.datetime(2021, 3, 26, 12, 8, 52, 84000),
#  'images': ['https://ecs7.tokopedia.net/img/cache/300/product-1/2019/2/11/338447/338447_5d85ec8d-51a1-41aa-bfd4-a0dfb66c7e40_720_720.jpg',
#   'https://ecs7.tokopedia.net/img/cache/300/product-1/2019/2/11/338447/338447_2dc40ee1-5111-4659-a9e6-6f0f60fa068d_720_720.jpg',
#   'https://ecs7.tokopedia.net/img/cache/300/product-1/2019/2/11/338447/338447_8e096802-772f-42f2-8c20-586639d6dbeb_720_720.jpg',
#   'https://ecs7.tokopedia.net/img/cache/300/product-1/2019/2/11/338447/338447_25a8d992-2bc3-43c7-a2f8-5c17dc6506b1_720_720.jpg'],
#  'cat_id_1': '62',
#  'cat_id_2': '3415',
#  'cat_id_3': '3613',
#  'stock': 999609,
#  'view': 5440,
#  'diskusi': 13,
#  'review': 66,
#  'rating': 5.0,
#  'rating_count': 66.0,
#  'sold': 429,
#  'tx': 173,
#  'diff_sold': [[25, 0], [26, 0]],
#  'sold_day_1': 0,
#  'sold_day_3': 0,
#  'sold_week': 0,
#  'sold_week_2': 0,
#  'sold_month': 0,
#  'diff_view': [[25, 0], [26, 0]],
#  'view_day_1': 0,
#  'view_day_3': 0,
#  'view_week': 0,
#  'view_week_2': 0,
#  'view_month': 0,
#  'diff_tx': [[25, 0], [26, 0]],
#  'tx_day_1': 0,
#  'tx_day_3': 0,
#  'tx_week': 0,
#  'tx_week_2': 0,
#  'tx_month': 0}

# %%
products = db.product.find({ '$text': { '$search': "baju koko" } }).sort("sold_day_3", pymongo.DESCENDING).limit(10)
products = list(products)
for prod in products:
    print(prod)
# Out:
# {'_id': 1102640805, 'shop': {'_id': 3791231, 'username': 'udebekade', 'percent_tx': 99.878, 'location': 'Kota Bandung', 'rating': 5, 'score_map': 12, 'kecepatan': 5}, 'itemid': 1102640805, 'name': 'Plastik klip plong 20x36 (30+6) plastik distro packing baju kaos READY - BENING TRANSP', 'price': 650, 'shopid': 3791231, 'url': 'https://www.tokopedia.com/udebekade/plastik-klip-plong-20x36-30-6-plastik-distro-packing-baju-kaos-ready-bening-transp', 'description': '', 'weight': 11, 'last_updated': datetime.datetime(2021, 3, 26, 13, 17, 11, 178000), 'images': ['https://ecs7.tokopedia.net/img/cache/300/product-1/2020/8/16/37787783/37787783_ef855b73-2ad9-4484-89e7-54dd6a81a6d1_1000_1000', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2020/8/21/1102640801/1102640801_c14fce17-7869-4e62-b5b7-16989468d9bc_700_700.jpg', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2020/8/21/1102640801/1102640801_7c08dfac-dadb-48a3-a39c-846e51c5cc08_700_700.jpg', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2020/8/21/1102640801/1102640801_27c86001-284f-44d0-88b5-04b78dd5642a_700_700.jpg'], 'cat_id_1': '984', 'cat_id_2': '991', 'cat_id_3': '1368', 'stock': 45190, 'view': 7165, 'diskusi': 0, 'review': 110, 'rating': 4.9, 'rating_count': 110.0, 'sold': 23962, 'tx': 222, 'diff_sold': [[22, 252], [23, 0], [24, 23942], [25, 0], [26, 20]], 'sold_day_1': 20, 'sold_day_3': 23962, 'sold_week': 24214, 'sold_week_2': 24214, 'sold_month': 24214, 'diff_view': [[22, 0], [23, 83], [24, 33], [25, 24], [26, 42]], 'view_day_1': 42, 'view_day_3': 99, 'view_week': 182, 'view_week_2': 182, 'view_month': 182, 'diff_tx': [[22, 4], [23, 0], [24, 221], [25, 0], [26, 1]], 'tx_day_1': 1, 'tx_day_3': 222, 'tx_week': 226, 'tx_week_2': 226, 'tx_month': 226, 'err_date': datetime.datetime(2021, 3, 24, 13, 15, 28, 463000)}
# {'_id': 358695389, 'shop': {'_id': 151605, 'username': 'dijeshop77', 'percent_tx': 86.728, 'location': 'Kab. Bogor', 'rating': 4.6, 'score_map': 9, 'kecepatan': 3}, 'itemid': 358695389, 'name': 'Renda rumbai / gombyok / rumbai halus mengkilap / renda baju /dekorasi', 'price': 5700, 'shopid': 151605, 'url': 'https://www.tokopedia.com/dijeshop77/renda-rumbai-gombyok-rumbai-halus-mengkilap-renda-baju-dekorasi', 'description': '', 'weight': 19, 'last_updated': datetime.datetime(2021, 3, 26, 14, 21, 1, 878000), 'images': ['https://ecs7.tokopedia.net/img/cache/300/product-1/2018/11/9/151605/151605_31894802-5bb2-4333-ba60-ca3cb6e4427f_1455_1455.jpg', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2018/11/9/151605/151605_d97dfd59-c349-484c-aac4-ada4e2530a32_1512_1512.jpg', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2019/3/12/358695389/358695389_adffd7af-3a45-4037-89b1-f776109e60dd_1512_1512.jpg', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2019/3/12/358695389/358695389_4bf89b18-1dde-41dc-b0d8-edad008db3e3_638_638.jpg', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2019/5/20/358695389/358695389_167c7179-64d5-4359-8a2f-949d9ed36c73_720_720.jpg'], 'cat_id_1': '54', 'cat_id_2': '11', 'stock': 2640, 'view': 4532, 'diskusi': 21, 'review': 15, 'rating': 4.8, 'rating_count': 15.0, 'sold': 9177, 'tx': 82, 'diff_sold': [[16, 0], [17, 0], [18, 8], [19, 0], [20, 0], [21, 0], [22, 0], [23, 0], [24, 9177], [25, 0], [26, 0]], 'sold_day_1': 0, 'sold_day_3': 9177, 'sold_week': 9177, 'sold_week_2': 9185, 'sold_month': 9185, 'diff_view': [[16, 8], [17, 1], [18, 10], [19, 2], [20, 1], [21, 0], [22, 14], [23, 2], [24, 16], [25, 5], [26, 13]], 'view_day_1': 13, 'view_day_3': 34, 'view_week': 51, 'view_week_2': 72, 'view_month': 72, 'diff_tx': [[16, 0], [17, 0], [18, 1], [19, 0], [20, 0], [21, 0], [22, 0], [23, 0], [24, 82], [25, 0], [26, 0]], 'tx_day_1': 0, 'tx_day_3': 82, 'tx_week': 82, 'tx_week_2': 83, 'tx_month': 83, 'err_date': datetime.datetime(2021, 3, 24, 14, 5, 37, 965000)}
# {'_id': 799492479, 'shop': {'_id': 2990980, 'username': 'kardustangerang', 'percent_tx': 98.984, 'location': 'Kab. Tangerang', 'rating': 4.9, 'score_map': 14, 'kecepatan': 5}, 'itemid': 799492479, 'name': 'Kardus / box pizza / baju / kue 30x30x8 cm', 'price': 4600, 'shopid': 2990980, 'url': 'https://www.tokopedia.com/kardustangerang/kardus-box-pizza-baju-kue-30x30x8-cm', 'description': '', 'weight': 200, 'last_updated': datetime.datetime(2021, 3, 26, 13, 17, 35, 744000), 'images': ['https://ecs7.tokopedia.net/img/cache/300/attachment/2020/4/23/158760670698810/158760670698810_01b3e8dd-e606-4773-908d-173dd60fe515.png', 'https://ecs7.tokopedia.net/img/cache/300/attachment/2020/4/23/158760670698821/158760670698821_bb841cb6-0025-4b8b-b0b1-b7f2093b61d7.png', 'https://ecs7.tokopedia.net/img/cache/300/attachment/2020/4/23/158760670698855/158760670698855_3bb4594a-d79b-4191-b12b-5105a3d7b4e0.png', 'https://ecs7.tokopedia.net/img/cache/300/attachment/2020/4/23/158760670698876/158760670698876_02249d7d-303e-45cb-91de-ccd447147577.png', 'https://ecs7.tokopedia.net/img/cache/300/attachment/2020/4/23/158760670698880/158760670698880_00eee339-f1c1-4963-aa3d-7fae32b7725b.png'], 'cat_id_1': '984', 'cat_id_2': '991', 'cat_id_3': '3731', 'stock': 996396, 'view': 4381, 'diskusi': 10, 'review': 84, 'rating': 4.9, 'rating_count': 84.0, 'sold': 8750, 'tx': 321, 'diff_sold': [[17, 0], [18, 0], [19, 0], [20, 10], [21, 0], [22, 0], [23, 0], [24, 0], [25, 0], [26, 8750]], 'sold_day_1': 8750, 'sold_day_3': 8750, 'sold_week': 8760, 'sold_week_2': 8760, 'sold_month': 8760, 'diff_view': [[17, 1], [18, 1], [19, 0], [20, 0], [21, 0], [22, 2], [23, 0], [24, 5], [25, 0], [26, 4]], 'view_day_1': 4, 'view_day_3': 9, 'view_week': 11, 'view_week_2': 13, 'view_month': 13, 'diff_tx': [[17, 0], [18, 0], [19, 0], [20, 1], [21, 0], [22, 0], [23, 0], [24, 0], [25, 0], [26, 321]], 'tx_day_1': 321, 'tx_day_3': 321, 'tx_week': 322, 'tx_week_2': 322, 'tx_month': 322, 'err_date': datetime.datetime(2021, 3, 26, 13, 17, 35, 744000)}
# {'_id': 1033726333, 'shop': {'_id': 8814911, 'username': 'boxworld-id', 'percent_tx': 100.0, 'location': 'Jakarta Barat', 'rating': 5, 'score_map': 9, 'kecepatan': 4}, 'itemid': 1033726333, 'name': 'Ear Lock 30x30x5 | Karton Kardus Box Pizza Die Cut Packaging Baju Kue', 'price': 4200, 'shopid': 8814911, 'url': 'https://www.tokopedia.com/boxworld-id/ear-lock-30x30x5-karton-kardus-box-pizza-die-cut-packaging-baju-kue', 'description': '', 'weight': 155, 'last_updated': datetime.datetime(2021, 3, 26, 14, 19, 5, 978000), 'images': ['https://ecs7.tokopedia.net/img/cache/300/product-1/2020/7/17/6056962/6056962_4ab7fbc1-15a2-4f52-9e27-1d4cb93febe7_1081_1081', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2020/7/17/6056962/6056962_08296b7f-f92a-4234-9b69-5d43c7dfb2a4_1081_1081', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2020/7/17/6056962/6056962_3548e11f-f4ae-473e-a4b4-d92bb385290d_1081_1081', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2020/7/17/6056962/6056962_436a8717-4949-4ab0-9c09-0110d558abd8_1081_1081', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2020/7/17/6056962/6056962_081d14b3-a571-46c1-9e61-08ecb7184b73_1081_1081'], 'cat_id_1': '54', 'cat_id_2': '2391', 'cat_id_3': '2394', 'stock': 837, 'view': 8378, 'diskusi': 4, 'review': 66, 'rating': 4.9, 'rating_count': 66.0, 'sold': 4110, 'tx': 137, 'diff_sold': [[17, 0], [18, 3920], [19, 10], [20, 0], [21, 0], [22, 100], [23, 0], [24, 4110], [25, 0], [26, 4110]], 'sold_day_1': 4110, 'sold_day_3': 8220, 'sold_week': 8320, 'sold_week_2': 12250, 'sold_month': 12250, 'diff_view': [[17, 5], [18, 8], [19, 6], [20, 2], [21, 0], [22, 15], [23, 17], [24, 4], [25, 11], [26, 5]], 'view_day_1': 5, 'view_day_3': 20, 'view_week': 54, 'view_week_2': 73, 'view_month': 73, 'diff_tx': [[17, 0], [18, 134], [19, 1], [20, 0], [21, 0], [22, 1], [23, 0], [24, 137], [25, 0], [26, 137]], 'tx_day_1': 137, 'tx_day_3': 274, 'tx_week': 275, 'tx_week_2': 410, 'tx_month': 410, 'err_date': datetime.datetime(2021, 3, 26, 14, 19, 5, 978000)}
# {'_id': 1030698506, 'shop': {'_id': 5867896, 'username': 'ktheo', 'percent_tx': 99.496, 'location': 'Jakarta Utara', 'rating': 4.9, 'score_map': 12, 'kecepatan': 5}, 'itemid': 1030698506, 'name': 'Dus Pizza / Brownies / Kue / Baju / 30 x 12 x 6 cm / Packaging Kardus', 'price': 1900, 'shopid': 5867896, 'url': 'https://www.tokopedia.com/ktheo/dus-pizza-brownies-kue-baju-30-x-12-x-6-cm-packaging-kardus', 'description': '', 'weight': 85, 'last_updated': datetime.datetime(2021, 3, 26, 13, 17, 11, 652000), 'images': ['https://ecs7.tokopedia.net/img/cache/300/VqbcmM/2020/10/6/b723e422-0d79-47b5-8ec9-350623ac704b.jpg', 'https://ecs7.tokopedia.net/img/cache/300/VqbcmM/2020/10/6/36b0ff9e-fe22-4e55-8c7c-12071f022a48.jpg'], 'cat_id_1': '984', 'cat_id_2': '991', 'cat_id_3': '1038', 'stock': 998573, 'view': 4052, 'diskusi': 8, 'review': 143, 'rating': 4.9, 'rating_count': 143.0, 'sold': 6709, 'tx': 268, 'diff_sold': [[22, 0], [23, 50], [24, 0], [25, 0], [26, 6709]], 'sold_day_1': 6709, 'sold_day_3': 6709, 'sold_week': 6759, 'sold_week_2': 6759, 'sold_month': 6759, 'diff_view': [[22, 9], [23, 8], [24, 11], [25, 6], [26, 10]], 'view_day_1': 10, 'view_day_3': 27, 'view_week': 44, 'view_week_2': 44, 'view_month': 44, 'diff_tx': [[22, 0], [23, 1], [24, 0], [25, 0], [26, 268]], 'tx_day_1': 268, 'tx_day_3': 268, 'tx_week': 269, 'tx_week_2': 269, 'tx_month': 269, 'err_date': datetime.datetime(2021, 3, 26, 13, 17, 11, 652000)}
# {'_id': 1196343821, 'shop': {'_id': 1089290, 'username': 'liciostore', 'percent_tx': 99.682, 'location': 'Jakarta Utara', 'rating': 4.8, 'score_map': 14, 'kecepatan': 4}, 'itemid': 1196343821, 'name': 'Hanger Gantungan Baju Kamar Mandi Perekat Suction Tempel Extra Strong - Transparant', 'price': 1499, 'shopid': 1089290, 'url': 'https://www.tokopedia.com/liciostore/hanger-gantungan-baju-kamar-mandi-perekat-suction-tempel-extra-strong-transparant', 'description': '', 'weight': 10, 'last_updated': datetime.datetime(2021, 3, 26, 14, 23, 7, 411000), 'images': ['https://ecs7.tokopedia.net/img/cache/300/VqbcmM/2020/12/18/557aece2-53fb-4b61-91df-d7447291f83e.jpg'], 'cat_id_1': '984', 'cat_id_2': '986', 'cat_id_3': '1003', 'stock': 4161, 'view': 7424, 'diskusi': 14, 'review': 269, 'rating': 4.7, 'rating_count': 269.0, 'sold': 6431, 'tx': 545, 'diff_sold': [[19, 20], [20, 20], [21, 0], [22, 0], [23, 10], [24, 0], [25, 6421], [26, 10]], 'sold_day_1': 10, 'sold_day_3': 6431, 'sold_week': 6461, 'sold_week_2': 6481, 'sold_month': 6481, 'diff_view': [[19, 13], [20, 9], [21, 0], [22, 21], [23, 11], [24, 7], [25, 6], [26, 9]], 'view_day_1': 9, 'view_day_3': 22, 'view_week': 63, 'view_week_2': 76, 'view_month': 76, 'diff_tx': [[19, 2], [20, 2], [21, 0], [22, 0], [23, 1], [24, 0], [25, 544], [26, 1]], 'tx_day_1': 1, 'tx_day_3': 545, 'tx_week': 548, 'tx_week_2': 550, 'tx_month': 550, 'err_date': datetime.datetime(2021, 3, 25, 14, 15, 27, 278000)}
# {'_id': 391392355, 'shop': {'_id': 2507494, 'username': 'icgcja', 'percent_tx': 98.578, 'location': 'Jakarta Pusat', 'rating': 4.7, 'score_map': 16, 'kecepatan': 5}, 'itemid': 391392355, 'name': 'HANDUK BAJU DEWASA GOL17 ANDUK BAJU TIDUR KARAKTER MULTIFUNGSI', 'price': 14800, 'shopid': 2507494, 'url': 'https://www.tokopedia.com/icgcja/handuk-baju-dewasa-gol17-anduk-baju-tidur-karakter-multifungsi', 'description': '', 'weight': 280, 'last_updated': datetime.datetime(2021, 3, 26, 14, 17, 8, 652000), 'images': ['https://ecs7.tokopedia.net/img/cache/300/product-1/2019/1/17/15593135/15593135_eac4028e-38d9-4401-b24f-a222ec0aaa0b_700_700.jpg', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2019/1/17/15593135/15593135_f80c5187-3017-4f09-a95e-6ff2570d2c36_700_700.jpg', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2019/1/17/15593135/15593135_3e6f6473-cd44-4f50-bb63-3d161adc14dc_700_700.jpg', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2019/1/17/15593135/15593135_053fb494-223d-46f2-a939-78a1a0df7f16_700_700.jpg'], 'cat_id_1': '984', 'cat_id_2': '986', 'cat_id_3': '3721', 'stock': 3098, 'view': 52670, 'diskusi': 201, 'review': 631, 'rating': 4.7, 'rating_count': 631.0, 'sold': 5900, 'tx': 1983, 'diff_sold': [[14, 0], [15, 0], [16, 0], [17, 2], [18, 1], [19, 0], [20, 1], [21, 0], [22, 0], [23, 5896], [24, 0], [25, 5898], [26, 2]], 'sold_day_1': 2, 'sold_day_3': 5900, 'sold_week': 11797, 'sold_week_2': 11800, 'sold_month': 11800, 'diff_view': [[14, 14], [15, 8], [16, 12], [17, 8], [18, 23], [19, 14], [20, 12], [21, 0], [22, 34], [23, 11], [24, 8], [25, 22], [26, 13]], 'view_day_1': 13, 'view_day_3': 43, 'view_week': 100, 'view_week_2': 179, 'view_month': 179, 'diff_tx': [[14, 0], [15, 0], [16, 0], [17, 1], [18, 1], [19, 0], [20, 1], [21, 0], [22, 0], [23, 1979], [24, 0], [25, 1981], [26, 2]], 'tx_day_1': 2, 'tx_day_3': 1983, 'tx_week': 3963, 'tx_week_2': 3965, 'tx_month': 3965, 'err_date': datetime.datetime(2021, 3, 25, 14, 5, 3, 714000)}
# {'_id': 1142566442, 'shop': {'_id': 686944, 'username': 'grosirclo', 'percent_tx': 94.682, 'location': 'Jakarta Selatan', 'rating': 4.8, 'score_map': 17, 'kecepatan': 5}, 'itemid': 1142566442, 'name': 'Baju Kaos Polos Oblong Soft cotton Combed 30s Oneck Murah S M L XL - Putih, S', 'price': 28500, 'shopid': 686944, 'url': 'https://www.tokopedia.com/grosirclo/baju-kaos-polos-oblong-soft-cotton-combed-30s-oneck-murah-s-m-l-xl-putih-s', 'description': '', 'weight': 180, 'last_updated': datetime.datetime(2021, 3, 26, 12, 13, 32, 173000), 'images': ['https://ecs7.tokopedia.net/img/cache/300/product-1/2019/11/6/5723707/5723707_454807cf-b0a2-46a4-95b8-aae6ce150eb6_1280_1280', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2019/11/6/5723707/5723707_50036467-81c2-4b24-8e37-3b3739c07be2_1280_1280', 'https://ecs7.tokopedia.net/img/cache/300/product-1/2019/11/6/5723707/5723707_8378168d-48e9-427f-b1cf-64366eb04ea9_1280_1280'], 'cat_id_1': '1759', 'cat_id_2': '1784', 'cat_id_3': '1808', 'stock': 479, 'view': 44349, 'diskusi': 152, 'review': 682, 'rating': 4.9, 'rating_count': 682.0, 'sold': 5807, 'tx': 1630, 'diff_sold': [[25, 0], [26, 5807]], 'sold_day_1': 5807, 'sold_day_3': 5807, 'sold_week': 5807, 'sold_week_2': 5807, 'sold_month': 5807, 'diff_view': [[25, 105], [26, 47]], 'view_day_1': 47, 'view_day_3': 152, 'view_week': 152, 'view_week_2': 152, 'view_month': 152, 'diff_tx': [[25, 0], [26, 1630]], 'tx_day_1': 1630, 'tx_day_3': 1630, 'tx_week': 1630, 'tx_week_2': 1630, 'tx_month': 1630}
# {'_id': 1518500018, 'shop': {'_id': 4797930, 'username': 'revenge11', 'percent_tx': 99.821, 'location': 'Jakarta Barat', 'rating': 4.8, 'score_map': 16, 'kecepatan': 5}, 'itemid': 1518500018, 'name': 'T-shirt Astronaut / Baju Kaos Distro Pria Tribe Hitam Pendek Slimfit - L', 'price': 29900, 'shopid': 4797930, 'url': 'https://www.tokopedia.com/revenge11/t-shirt-astronaut-baju-kaos-distro-pria-tribe-hitam-pendek-slimfit-l', 'description': '', 'weight': 190, 'last_updated': datetime.datetime(2021, 3, 26, 12, 13, 23, 328000), 'images': ['https://ecs7.tokopedia.net/img/cache/300/product-1/2019/11/19/41483380/41483380_3283a833-8a0c-4dc1-89d7-25867f576c1e_1280_1280'], 'cat_id_1': '1759', 'cat_id_2': '1784', 'cat_id_3': '1808', 'stock': 752, 'view': 383951, 'diskusi': 429, 'review': 1803, 'rating': 4.8, 'rating_count': 1803.0, 'sold': 5243, 'tx': 4613, 'diff_sold': [[25, 0], [26, 5243]], 'sold_day_1': 5243, 'sold_day_3': 5243, 'sold_week': 5243, 'sold_week_2': 5243, 'sold_month': 5243, 'diff_view': [[25, 432], [26, 746]], 'view_day_1': 746, 'view_day_3': 1178, 'view_week': 1178, 'view_week_2': 1178, 'view_month': 1178, 'diff_tx': [[25, 0], [26, 4613]], 'tx_day_1': 4613, 'tx_day_3': 4613, 'tx_week': 4613, 'tx_week_2': 4613, 'tx_month': 4613}
# {'_id': 1172850412, 'shop': {'_id': 7827497, 'username': 'angolaofficia', 'percent_tx': 99.419, 'location': 'Kab. Tangerang', 'rating': 4.8, 'score_map': 18, 'kecepatan': 5}, 'itemid': 1172850412, 'name': 'Rak Laci Storage Penyimpanan Rak Baju Tempat Baju Rak Kamar Mandi C19 - Putih', 'price': 63000, 'shopid': 7827497, 'url': 'https://www.tokopedia.com/angolaofficia/rak-laci-storage-penyimpanan-rak-baju-tempat-baju-rak-kamar-mandi-c19-putih', 'description': '', 'weight': 800, 'last_updated': datetime.datetime(2021, 3, 26, 14, 33, 35, 86000), 'images': ['https://ecs7.tokopedia.net/img/cache/300/VqbcmM/2020/10/9/e31519ed-f327-4eae-9627-68e9a07c487b.jpg', 'https://ecs7.tokopedia.net/img/cache/300/VqbcmM/2020/9/12/7f49d806-3515-4030-9d61-61214806a350.jpg', 'https://ecs7.tokopedia.net/img/cache/300/VqbcmM/2020/9/12/0c822c32-c369-4dd8-8336-01b20d881d3c.jpg', 'https://ecs7.tokopedia.net/img/cache/300/VqbcmM/2020/9/12/16acf71e-7eb9-4801-92fd-653d00829e50.jpg', 'https://ecs7.tokopedia.net/img/cache/300/VqbcmM/2020/9/12/6087d517-4bb7-4418-be29-f1d6dd4931dd.jpg', 'https://ecs7.tokopedia.net/img/cache/300/VqbcmM/2020/10/9/119aa435-e146-4cce-a192-a4109da508d6.jpg'], 'cat_id_1': '984', 'cat_id_2': '991', 'cat_id_3': '1044', 'stock': 958, 'view': 98725, 'diskusi': 48, 'review': 896, 'rating': 4.9, 'rating_count': 896.0, 'sold': 5121, 'tx': 1931, 'diff_sold': [[17, 37], [18, 26], [19, 43], [20, 31], [21, 0], [22, 49], [23, 16], [24, 0], [25, 5111], [26, 10]], 'sold_day_1': 10, 'sold_day_3': 5121, 'sold_week': 5217, 'sold_week_2': 5323, 'sold_month': 5323, 'diff_view': [[17, 368], [18, 348], [19, 278], [20, 1660], [21, 0], [22, 338], [23, 134], [24, 113], [25, 108], [26, 171]], 'view_day_1': 171, 'view_day_3': 392, 'view_week': 2524, 'view_week_2': 3518, 'view_month': 3518, 'diff_tx': [[17, 17], [18, 10], [19, 16], [20, 9], [21, 0], [22, 23], [23, 14], [24, 0], [25, 1927], [26, 4]], 'tx_day_1': 4, 'tx_day_3': 1931, 'tx_week': 1977, 'tx_week_2': 2020, 'tx_month': 2020, 'err_date': datetime.datetime(2021, 3, 25, 14, 32, 42, 187000)}

# %% [markdown]
# # insight Produk

# %%
import requests
from PIL import Image
import io

# %%
def get_image(url):
    res = requests.get(url, stream=True)
    image = Image.open(io.BytesIO(res.content))
    return image

# %%
def plotting_prod(products):
    for prod in products:
        
        image = get_image(prod['images'][0])
        
        display(image)
        print('Harga : {}'.format(prod['price']))
        print('Name : {}'.format(prod['name']))

# %%
plotting_prod(products)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x300 at 0x1E68DF6E4E0>
# Harga : 650
# Name : Plastik klip plong 20x36 (30+6) plastik distro packing baju kaos READY - BENING TRANSP
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x1E68BE76D68>
# Harga : 5700
# Name : Renda rumbai / gombyok / rumbai halus mengkilap / renda baju /dekorasi
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x400 at 0x1E68BE76B38>
# Harga : 4600
# Name : Kardus / box pizza / baju / kue 30x30x8 cm
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x300 at 0x1E68BE76240>
# Harga : 4200
# Name : Ear Lock 30x30x5 | Karton Kardus Box Pizza Die Cut Packaging Baju Kue
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x1E68BE76908>
# Harga : 1900
# Name : Dus Pizza / Brownies / Kue / Baju / 30 x 12 x 6 cm / Packaging Kardus
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x299 at 0x1E68BE76D68>
# Harga : 1499
# Name : Hanger Gantungan Baju Kamar Mandi Perekat Suction Tempel Extra Strong - Transparant
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x1E68BE76390>
# Harga : 14800
# Name : HANDUK BAJU DEWASA GOL17 ANDUK BAJU TIDUR KARAKTER MULTIFUNGSI
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x1E68BE76550>
# Harga : 28500
# Name : Baju Kaos Polos Oblong Soft cotton Combed 30s Oneck Murah S M L XL - Putih, S
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x1E68BE76128>
# Harga : 29900
# Name : T-shirt Astronaut / Baju Kaos Distro Pria Tribe Hitam Pendek Slimfit - L
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x1E68BE76908>
# Harga : 63000
# Name : Rak Laci Storage Penyimpanan Rak Baju Tempat Baju Rak Kamar Mandi C19 - Putih
