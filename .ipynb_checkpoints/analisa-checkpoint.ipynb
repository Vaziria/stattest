# %% [markdown]
# # Observasi

# %%
import json
import pymongo
from pymongo import MongoClient

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Apply the default theme
sns.set_theme()

# %% [markdown]
# # Pipeline

# %% [markdown]
# ## category

# %%
with open('category.json', 'r') as out:
    data = json.load(out)
    data = data[0]

# %%
datas = data['data']['categoryAllListLite']['categories']

# %%
def find_categ_name(id):
    for data in datas:
        if str(id) == str(data['id']):
            return data['name']
    return None

# %%
def categ_to_name(datas):
    for data in datas:
        name = find_categ_name(data['_id'])
        data['_id'] = name
        
    return datas

# %% [markdown]
# # Connecting Mongo

# %%
client = MongoClient('localhost:9700')
db = client.tokpedstat

# %% [markdown]
# # common function

# %%
def grafik(df, dimensi=[13, 9], name=None):
    fig_dims = dimensi
    fig, ax = plt.subplots(figsize=fig_dims)

    g = sns.barplot(data = df, x='_id', y='total', ax=ax)
    g.set_xticklabels(g.get_xticklabels(), rotation=40)
    
    if name:
        fig.savefig('img/{}.png'.format(name))
        
    plt.show(g)

# %%
db.product.count()
# Out:
# f:\python3\environment\test\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 1851483

# %% [markdown]
# # Stat By Category

# %%
aggr = [
    {
        "$group": {
            "_id": "$cat_id_1",
            "total": { "$sum": 1 }
        }
    }
]

hasil = db.product.aggregate(aggr)
hasil = list(hasil)
hasil = categ_to_name(hasil)
df = pd.DataFrame.from_records(hasil)
df = df.fillna(value='kosong')

# %%
grafik(df, (15,8), 'kategori')

# %% [markdown]
# # Timeline created data

# %%
aggr = [
    {
        "$group": {
            "_id": { "$dateToString": { "format": "%Y-%m-%d", "date": "$created" } },
            "total": { "$sum": 1 }
        }
    },
    { "$sort": { '_id': 1 } },
]

hasilc = db.product.aggregate(aggr)
hasilc = list(hasilc)
df = pd.DataFrame.from_records(hasilc)
df = df.fillna(value='kosong')

# %%
grafik(df, (15,8), 'created')

# %% [markdown]
# ## Without null Value

# %%
cleanhasilc = list(filter(lambda x:bool(x), hasilc))
df = pd.DataFrame.from_records(cleanhasilc)
df.describe()
# Out:
#               total
# count  2.900000e+01
# mean   6.384424e+04
# std    2.904901e+05
# min    2.377000e+03
# 25%    6.175000e+03
# 50%    1.011600e+04
# 75%    1.392000e+04
# max    1.574080e+06

# %%
grafik(df, (15,8), 'created_not_null')

# %% [markdown]
# # Checking Last up Data

# %%
aggr = [ 
    {
        "$group": {
            "_id": { "$dateToString": { "format": "%Y-%m-%d", "date": "$last_updated" } },
            "total": { "$sum": 1 }
        }
    }
]

hasillast = db.product.aggregate(aggr)
hasillast = list(hasillast)
df = pd.DataFrame.from_records(hasillast)
df = df.fillna(value='kosong')
df.describe()
# Out:
#            total
# count        1.0
# mean   1851483.0
# std          NaN
# min    1851483.0
# 25%    1851483.0
# 50%    1851483.0
# 75%    1851483.0
# max    1851483.0

# %%
grafik(df, (15,8), 'last_updated')

# %% [markdown]
# # Statistik Toko

# %%
aggr = [
    {
        "$group": {
            "_id": { "$dateToString": { "format": "%Y-%m-%d", "date": "$created" } },
            "total": { "$sum": 1 }
        }
    },
    { "$sort": { '_id': 1 } }
]

hasilc = db.toko.aggregate(aggr)
hasilc = list(hasilc)
df = pd.DataFrame.from_records(hasilc)
df = df.fillna(value='kosong')

# %%
grafik(df, (15,8), 'shop_created')

# %%
cleanhasilc = list(filter(lambda x:bool(x), hasilc))
df = pd.DataFrame.from_records(cleanhasilc)

# %%
grafik(df, (15,8), 'shop_created_notnull')

# %%
aggr = [
    { "$match": { "rating": { "$gte": 5 } }},
    {
        "$group": {
            "_id": "$location",
            "total": { "$sum": 1 }
        }
    },
    { "$sort": { "total": -1 } },
    { "$limit": 20 }
]

hasil = db.toko.aggregate(aggr)
hasil = list(hasil)

# %%
df = pd.DataFrame.from_records(hasil)
df = df.fillna(value='kosong')

fig_dims = (15, 11)
fig, ax = plt.subplots(figsize=fig_dims)

g = sns.barplot(data = df, x='_id', y='total', ax=ax)
g.set_xticklabels(g.get_xticklabels(), rotation=40)
plt.show(g)

# %% [markdown]
# # toko

# %%
db.toko.find_one()
# Out:
# {'_id': 338447,
#  'shopid': 338447,
#  'username': 'ferrygolf75',
#  'url': 'https://tokopedia.com/ferrygolf75',
#  'city_name': 'Kota Administrasi Jakarta Timur',
#  'district_name': 'Makasar',
#  'jum_product': 86,
#  'sold': 4992,
#  'tx': 2317,
#  'percent_tx': 97.64,
#  'location': 'Jakarta Timur',
#  'rating': 4.8,
#  'review': 1191,
#  'score_map': 11,
#  'score': 5348,
#  'kep_bad': 0,
#  'kep_good': 66,
#  'kep_neutral': 4,
#  'kecepatan': 4,
#  'last_updated': datetime.datetime(2021, 3, 28, 3, 18, 37, 507000)}

# %%
aggr = [
    {
        "$group": {
            "_id": "$kecepatan",
            "total": { "$sum": 1 }
        }
    },
    { "$sort": { "total": -1 } },
    { "$limit": 20 }
]

hasil = db.toko.aggregate(aggr)
hasil = list(hasil)

# %%
df = pd.DataFrame.from_records(hasil)
df = df.fillna(value='kosong')

fig_dims = (15, 11)
fig, ax = plt.subplots(figsize=fig_dims)

g = sns.barplot(data = df, x='_id', y='total', ax=ax)
g.set_xticklabels(g.get_xticklabels(), rotation=40)
plt.show(g)

# %% [markdown]
# # query data

# %%
db.product.count()
# Out:
# f:\python3\environment\test\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 1851483

# %% [markdown]
# # stat produk

# %%
db.product.find_one()
# Out:
# {'_id': 406936069,
#  'shop': {'_id': 338447,
#   'username': 'ferrygolf75',
#   'percent_tx': 97.635,
#   'location': 'Jakarta Timur',
#   'rating': 4.8,
#   'score_map': 11,
#   'kecepatan': 4},
#  'itemid': 406936069,
#  'name': 'Tee Karet Driving Golf Rubber 5,6,7',
#  'price': 25000,
#  'shopid': 338447,
#  'url': 'https://www.tokopedia.com/ferrygolf75/tee-karet-driving-golf-rubber-5-6-7',
#  'description': '',
#  'weight': 10,
#  'last_updated': datetime.datetime(2021, 3, 29, 12, 35, 57, 71000),
#  'images': ['https://ecs7.tokopedia.net/img/cache/300/product-1/2019/2/11/338447/338447_5d85ec8d-51a1-41aa-bfd4-a0dfb66c7e40_720_720.jpg',
#   'https://ecs7.tokopedia.net/img/cache/300/product-1/2019/2/11/338447/338447_2dc40ee1-5111-4659-a9e6-6f0f60fa068d_720_720.jpg',
#   'https://ecs7.tokopedia.net/img/cache/300/product-1/2019/2/11/338447/338447_8e096802-772f-42f2-8c20-586639d6dbeb_720_720.jpg',
#   'https://ecs7.tokopedia.net/img/cache/300/product-1/2019/2/11/338447/338447_25a8d992-2bc3-43c7-a2f8-5c17dc6506b1_720_720.jpg'],
#  'cat_id_1': '62',
#  'cat_id_2': '3415',
#  'cat_id_3': '3613',
#  'stock': 999609,
#  'view': 5463,
#  'diskusi': 13,
#  'review': 66,
#  'rating': 5.0,
#  'rating_count': 66.0,
#  'sold': 429,
#  'tx': 173,
#  'diff_sold': [[25, 0], [26, 0], [27, 0], [28, 0], [29, 0]],
#  'sold_day_1': 0,
#  'sold_day_3': 0,
#  'sold_week': 0,
#  'sold_week_2': 0,
#  'sold_month': 0,
#  'diff_view': [[25, 0], [26, 0], [27, 20], [28, 0], [29, 3]],
#  'view_day_1': 3,
#  'view_day_3': 23,
#  'view_week': 23,
#  'view_week_2': 23,
#  'view_month': 23,
#  'diff_tx': [[25, 0], [26, 0], [27, 0], [28, 0], [29, 0]],
#  'tx_day_1': 0,
#  'tx_day_3': 0,
#  'tx_week': 0,
#  'tx_week_2': 0,
#  'tx_month': 0}

# %% [markdown]
# # insight Produk

# %%
import requests
from PIL import Image
import io

# %%
def get_image(url):
    res = requests.get(url, stream=True)
    image = Image.open(io.BytesIO(res.content))
    return image

# %%
def plotting_prod(products):
    for prod in products:
        
        image = get_image(prod['images'][0])
        
        display(image)
        print('Harga : {}'.format(prod['price']))
        print('Name : {}'.format(prod['name']))

# %%
products = db.product.find({ '$text': { '$search': "gamis kafir" } } ).sort("sold_day_3", pymongo.DESCENDING).limit(10)
products = list(products)

# %%
plotting_prod(products)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x22D5AFA0F28>
# Harga : 54900
# Name : RUMANA KID | GAMIS SYARI ANAK | BAJU MUSLIM ANAK PEREMPUAN | BAJUANAK
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x22D5AE3F860>
# Harga : 139700
# Name : Jubah Pria Zein / Jubah Gamis Pria / GRATIS Peci Rajut
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x22D5AFA0E10>
# Harga : 119000
# Name : Gamis / Baju / Pakaian Wanita Muslim Binaiya syari set 3in1
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x22D5AF86668>
# Harga : 139000
# Name : Jubah Ikhwan / Gamis /Koko Pria Nyaman dan Adem
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x22D5AF867B8>
# Harga : 1550
# Name : PLASTIK KLIP KEMASAN ZIPLOCK BAJU / GAMIS / JAKET / SEPATU + SABLON - Hitam
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x22D5AF86860>
# Harga : 28000
# Name : slim n lift tanktop pria singlet pria kaos polos baju kaos baju gamis
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x22D5AF86908>
# Harga : 45000
# Name : Plastik Pelindung baju Gamis Dress long ukuran 55x130 1 Lusin
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x22D5AF868D0>
# Harga : 38900
# Name : SABBINA MAXY | KOTAK SABINA | GAMIS KATUN | BAJU GAMIS WANITA
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x22D5AF86860>
# Harga : 74900
# Name : YUMNA SYAR'I - GAMIS SET SYARII / BAJU GAUN MUSLIM/DRESS HIJAB MODERN
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x22D5AF86908>
# Harga : 149700
# Name : Jubah Pria Zain Manset / Jubah Gamis Pria / GRATIS Peci Rajut
